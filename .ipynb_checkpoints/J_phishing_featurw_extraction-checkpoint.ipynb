# %%
# packages
import pandas as pd
from urllib.parse import urlparse,urlencode
import re
from bs4 import BeautifulSoup
import requests
import whois
import urllib.request
from datetime import datetime
import time
import socket
from urllib.error import HTTPError
from cython.parallel import prange

# %%
from datetime import datetime
itime = datetime.now()
for i in prange(0,10000):
    pass
ftime = datetime.now()
print(ftime-itime)
# Out:
# 0:00:00.000997

# %%
computer_raw_data=pd.read_csv("new_phishing_urls.txt",header=None,names=['urls'])
computer_raw_data.head(10)
# Out:
#                                                 urls
# 0    http://asesoresvelfit.com/media/datacredito.co/
# 1  http://caixa.com.br.fgtsagendesaqueconta.com/c...
# 2         http://hissoulreason.com/js/homepage/home/
# 3    http://unauthorizd.newebpage.com/webapps/66fbf/
# 4                          http://133.130.103.10/23/
# 5  http://dj00.co.vu/css/?bsoul=Qg@xIHW%//yh/en/?...
# 6                    http://133.130.103.10/21/logar/
# 7  http://httpssicredi.esy.es/servico/sicredi/val...
# 8  http://gamesaty.ga/wp-content///yh/en/?i=31416...
# 9     http://luxuryupgradepro.com/ymailNew/ymailNew/

# %%
rows = len(computer_raw_data)
rows
# Out:
# 993

# %%
cd = None
class FeatureExtraction:
    def __init__(self):
        pass
    
    def getProtocol(self,url):
        return urlparse(url).scheme
    
    def getDomain(self,url):
        return urlparse(url).netloc
    
    def getPath(self,url):
        return urlparse(url).path
    
    def havingIP(self,url):
        """If the domain part has IP then it is phishing otherwise legitimate"""
        match=re.search('(([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\/)|'  #IPv4
                    '((0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\/)'  #IPv4 in hexadecimal
                    '(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}',url)     #Ipv6
        if match:
            #print match.group()
            return 1            # phishing
        else:
            #print 'No matching pattern found'
            return 0            # legitimate
    
    def long_url(self,url):
        """This function is defined in order to differntiate website based on the length of the URL"""
        if len(url) < 54:
            return 0            # legitimate
        elif len(url) >= 54 and len(url) <= 75:
            return 2            # suspicious
        else:
            return 1            # phishing
    
    def have_at_symbol(self,url):
        """This function is used to check whether the URL contains @ symbol or not"""
        if "@" in url:
            return 1            # phishing
        else:
            return 0            # legitimate
    
    def redirection(self,url):
        """If the url has symbol(//) after protocol then such URL is to be classified as phishing """
        if "//" in urlparse(url).path:
            return 1            # phishing
        else:
            return 0            # legitimate
        
    def prefix_suffix_separation(self,url):
        """If the domain has '-' symbol then it is considered as phishing site"""
        if "-" in urlparse(url).netloc:
            return 1            # phishing
        else:
            return 0            # legitimate
        
    def sub_domains(self,url):
        """If the url has more than 3 dots then it is a phishing"""
        if url.count(".") < 3:
            return 0            # legitimate
        elif url.count(".") == 3:
            return 2            # suspicious
        else:
            return 1            # phishing
        
    def shortening_service(self,url):
        """Tiny URL -> phishing otherwise legitimate"""
        match=re.search('bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|'
                    'yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|'
                    'short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|'
                    'doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|'
                    'db\.tt|qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|'
                    'q\.gs|is\.gd|po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|'
                    'x\.co|prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|tr\.im|link\.zip\.net',url)
        if match:
            return 1               # phishing
        else:
            return 0               # legitimate
        
    
    def web_traffic(self,url):
        try:
            rank = BeautifulSoup(urllib.request.urlopen("http://data.alexa.com/data?cli=10&dat=s&url=" + url).read(), "xml").find("REACH")['RANK']
        except TypeError:
            return 1
        except HTTPError:
            return 2
        rank= int(rank)
        if (rank<100000):
            return 0
        else:
            return 2
        
    def domain_registration_length(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
        except:
            dns = 1
        
        if dns == 1:
            return 1      #phishing
        else:
            expiration_date = domain_name.expiration_date
            today = time.strftime('%Y-%m-%d')
            today = datetime.strptime(today, '%Y-%m-%d')
            if expiration_date is None:
                return 1
            elif type(expiration_date) is list or type(today) is list :
                return 2     #If it is a type of list then we can't select a single value from list. So,it is regarded as suspected website  
            else:
                creation_date = domain_name.creation_date
                expiration_date = domain_name.expiration_date
                if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
                    try:
                        creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
                        expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
                    except:
                        return 2
                registration_length = abs((expiration_date - today).days)
                if registration_length / 365 <= 1:
                    return 1 #phishing
                else:
                    return 0 # legitimate
            
    def age_domain(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
        except:
            dns = 1
        
        if dns == 1:
            return 1
        else:
            creation_date = domain_name.creation_date
            expiration_date = domain_name.expiration_date
            if (isinstance(creation_date,str) or isinstance(expiration_date,str)):
                try:
                    creation_date = datetime.strptime(creation_date,'%Y-%m-%d')
                    expiration_date = datetime.strptime(expiration_date,"%Y-%m-%d")
                except:
                    return 2
            if ((expiration_date is None) or (creation_date is None)):
                return 1
            elif ((type(expiration_date) is list) or (type(creation_date) is list)):
                return 2
            else:
                ageofdomain = abs((expiration_date - creation_date).days)
                if ((ageofdomain/30) < 6):
                    return 1
                else:
                    return 0
     
    
    def dns_record(self,url):
        dns = 0
        try:
            domain_name = whois.whois(urlparse(url).netloc)
            #rint(domain_name)
        except:
            dns = 1
        
        if dns == 1:
            return 1
        else:
            return 0
        
   
    def statistical_report(self,url):
        hostname = url
        h = [(x.start(0), x.end(0)) for x in re.finditer('https://|http://|www.|https://www.|http://www.', hostname)]
        z = int(len(h))
        if z != 0:
            y = h[0][1]
            hostname = hostname[y:]
            h = [(x.start(0), x.end(0)) for x in re.finditer('/', hostname)]
            z = int(len(h))
            if z != 0:
                hostname = hostname[:h[0][0]]
        url_match=re.search('at\.ua|usa\.cc|baltazarpresentes\.com\.br|pe\.hu|esy\.es|hol\.es|sweddy\.com|myjino\.ru|96\.lt|ow\.ly',url)
        try:
            ip_address = socket.gethostbyname(hostname)
            ip_match=re.search('146\.112\.61\.108|213\.174\.157\.151|121\.50\.168\.88|192\.185\.217\.116|78\.46\.211\.158|181\.174\.165\.13|46\.242\.145\.103|121\.50\.168\.40|83\.125\.22\.219|46\.242\.145\.98|107\.151\.148\.44|107\.151\.148\.107|64\.70\.19\.203|199\.184\.144\.27|107\.151\.148\.108|107\.151\.148\.109|119\.28\.52\.61|54\.83\.43\.69|52\.69\.166\.231|216\.58\.192\.225|118\.184\.25\.86|67\.208\.74\.71|23\.253\.126\.58|104\.239\.157\.210|175\.126\.123\.219|141\.8\.224\.221|10\.10\.10\.10|43\.229\.108\.32|103\.232\.215\.140|69\.172\.201\.153|216\.218\.185\.162|54\.225\.104\.146|103\.243\.24\.98|199\.59\.243\.120|31\.170\.160\.61|213\.19\.128\.77|62\.113\.226\.131|208\.100\.26\.234|195\.16\.127\.102|195\.16\.127\.157|34\.196\.13\.28|103\.224\.212\.222|172\.217\.4\.225|54\.72\.9\.51|192\.64\.147\.141|198\.200\.56\.183|23\.253\.164\.103|52\.48\.191\.26|52\.214\.197\.72|87\.98\.255\.18|209\.99\.17\.27|216\.38\.62\.18|104\.130\.124\.96|47\.89\.58\.141|78\.46\.211\.158|54\.86\.225\.156|54\.82\.156\.19|37\.157\.192\.102|204\.11\.56\.48|110\.34\.231\.42',ip_address)  
        except:
            return 1

        if url_match:
            return 1
        else:
            return 0
        
    def https_token(self,url):
        match=re.search('https://|http://',url)
        try:
            if match.start(0)==0 and match.start(0) is not None:
                url=url[match.end(0):]
                match=re.search('http|https',url)
                if match:
                    return 1
                else:
                    return 0
        except:
            return 1

# %%
#features
protocol = []
domain = []
path = []
having_ip = []
len_url = []
having_at_symbol = []
redirection_symbol = []
prefix_suffix_separation = []
sub_domains = []
tiny_url = []
abnormal_url = []
web_traffic = []
domain_registration_length = []
dns_record = []
statistical_report = []
age_domain = []
http_tokens = []

# %%
# object creation
fe = FeatureExtraction()
rows = len(computer_raw_data["urls"])

for i in range(0,rows):
    url=computer_raw_data["urls"][i]
    print(i ),print(url)
    protocol.append(fe.getProtocol(url))
    path.append(fe.getPath(url))
    domain.append(fe.getDomain(url))
    having_ip.append(fe.havingIP(url))
    len_url.append(fe.long_url(url))
    having_at_symbol.append(fe.have_at_symbol(url))
    redirection_symbol.append(fe.redirection(url))
    prefix_suffix_separation.append(fe.prefix_suffix_separation(url))
    sub_domains.append(fe.sub_domains(url))
    tiny_url.append(fe.shortening_service(url))
    web_traffic.append(fe.web_traffic(url))
    domain_registration_length.append(fe.domain_registration_length(url))
    dns_record.append(fe.dns_record(url))
    statistical_report.append(fe.statistical_report(url))
    age_domain.append(fe.age_domain(url))
    http_tokens.append(fe.https_token(url))
# Out:
# 0
# http://asesoresvelfit.com/media/datacredito.co/
# 1
# http://caixa.com.br.fgtsagendesaqueconta.com/consulta8523211/principal.php?seg=11
# 2
# http://hissoulreason.com/js/homepage/home/
# 3
# http://unauthorizd.newebpage.com/webapps/66fbf/
# 4
# http://133.130.103.10/23/
# 5
# http://dj00.co.vu/css/?bsoul=Qg@xIHW%//yh/en/?i=34453&amp;i=34453
# 6
# http://133.130.103.10/21/logar/
# 7
# http://httpssicredi.esy.es/servico/sicredi/validarclientes/mobi/index.php
# 8
# http://gamesaty.ga/wp-content///yh/en/?i=31416&amp;i=31416
# 9
# http://luxuryupgradepro.com/ymailNew/ymailNew/
# 10
# http://133.130.103.10/1/
# 11
# http://133.130.103.10/24/sicredi/psmlId/31/paneid/index.htm
# 12
# http://smscaixaacesso.hol.es
# 13
# http://133.130.103.10/7/SIIBC/siwinCtrl.php
# 14
# http://tinyurl.com/kjmmw57
# 15
# http://wrightlandscapes.org/no/T/Y1.html
# 16
# http://mautic.eto-cms.ru/themes/goldstar/mtbonline/newmandt/
# 17
# http://ginatringali.com//al/alibaba21012015/alibaba21012015/666/index.html
# 18
# https://staticmail.000webhostapp.com/
# 19
# http://umeda.com.br/bba/BOA/home/
# 20
# http://krishworldwide.com/BackUp/under/js/ayo1/index.html
# 21
# http://yahoo.co.in/email_open_log_pic.php?mid=9f8fd3e2a108a256bff453d09c965c25&amp;s=a
# 22
# http://www.avcc.ac.in/fonts/1/wropboxp/login.html
# 23
# http://craig-hallum.ga/sgg/1/login.htm
# 24
# http://www.verification-mobile-nab.com/cgi/e8e11a52ed442dc4b327eaa2f19c2521/login/
# 25
# http://verification-mobile-nab.com/cgi/e8e11a52ed442dc4b327eaa2f19c2521/login/
# 26
# http://www.justpiddlinboutique.com/win/image.htm
# 27
# http://vcsolutionscorp.com/Block/image.htm
# 28
# http://almasur.com/wp-includes/pomo/docusign17/
# 29
# http://asesoresvelfit.com/media/cms/datacredito.co/
# 30
# https://getpeopleplus.com/EserviceMain/irs/ir/index.html
# 31
# https://taeamigo.com/EserviceMain/irs/ir/index.html
# 32
# https://elmundo-latino.com/ir/index.html
# 33
# http://sociopremiosedescontos.com/cadastro/
# 34
# http://cartaopremiadosicoob.com
# 35
# http://ms-0ffice365supportplanquota.us.com0203499083934.elegantvapour.co.uk/0-009021--0203499083934.l3992389100283901233232400349902132443940090132/hotmail.login/client_id=00000002-0000-0ff1-ce00-000000000000&amp;/000-pc.domain/officelogin1.html?run=login_cmd&amp;statuts=f17ca2c829680ada2fec9fc87bc5f606913063b5e3c451761e1f9d5888ada562
# 36
# http://www.travrica.com/ntime/T/Y1.html
# 37
# http://system-tnc.esy.es/recovery-chekpoint-login.html
# 38
# http://sandralucashyde.org/login.yahoo/yahoo.com%20[Lastet%20Update]/indexz.html
# 39
# http://alexanderpetricek.com/EserviceMain/irs/ir/index.html
# 40
# http://di15.co.vu/css/?bsoul=P)HdNhwY//yh/en/?i=31416&amp;i=31416
# 41
# http://sicredisms.ignitiondomain.com/2017/validarclientes/mobi/index.php
# 42
# https://rajspaces.com/EserviceDLAcct/irs/ir/index.html
# 43
# http://fb-systemapps.esy.es/recovery-chekpoint-login.html
# 44
# https://signin-activitysupport.helpcenter-supportfraudsignin.com/mpp/signin/f341/
# 45
# http://www.citadelchurchjax.com/wp-admin/validateowa/owa/WebAdmin/Outlook%20Web%20App.htm
# 46
# http://pradochaui.com.br/criptografado1/index1.php
# 47
# http://simnokomun.lt/upload/omo/newgd2/newgd/moole/index.php
# 48
# http://di11.co.vu/css/?bsoul=znr($Jxd//yh/en/?i=34639&amp;i=34639
# 49
# http://www.alligator.site/wp-content/wall/gallary/fin/
# 50
# http://tinyurl.com/le5tcvf
# 51
# http://tinyurl.com/ll59xhm
# 52
# https://tr.im/1e0rQ
# 53
# https://www.gommetermiche.it/administrator/modules/auth.att.secure/login.htm
# 54
# http://indonesianwonderagate.com/zee/validate.htm?utm_source=tr.im&amp;utm_medium=no_referer&amp;utm_campaign=tr.im%2F1e0rQ&amp;utm_content=direct_input
# 55
# http://tinyurl.com/ll59xhm
# 56
# http://consultafgts.esy.es/home
# 57
# http://www.ultrakoz.com/uploads/files/reloadedatt.net.html
# 58
# http://www.blackabba.com/sign-on/yahoo/Y1.html
# 59
# http://carretroller.com.br/sss/image.htm
# 60
# https://www.mamujutengahkab.go.id/terasconfig/www.att.net/
# 61
# http://sandralucashyde.org/login.yahoo/yahoo.com%20[Lastet%20Update]/indexz.html
# 62
# http://extratoinativos.com/Inativos/
# 63
# http://consultar-fgts.com/1index.php
# 64
# http://portal-consultafgts.com/caixa.gov.br/pages/inter/index.php
# 65
# http://ni1232966-3.web20.nitrado.hosting/finance/fnce/
# 66
# http://fgtsliberacao.com/processa.php
# 67
# https://jokextreme.com/irs.return/Payment%20Lookup.html
# 68
# http://fb-safetyhelp.esy.es/recovery-chekpoint-login.html
# 69
# http://fb-securitypolicy101inc.esy.es/recovery-chekpoint-login.html
# 70
# http://fb-securityaccountlogincheck808.esy.es/recovery-chekpoint-login.html
# 71
# http://laghaimrevolution.com/sign-on/yahoo/Y1.html
# 72
# http://settings-acct024631.esy.es/recovery-chekpoint-login.html
# 73
# http://horizongarments.com/Asher/image.htm
# 74
# http://shittyurl.org/5u
# 75
# http://ni1232966-4.web16.nitrado.hosting/ye/cmbr/
# 76
# http://system-support-il.hol.es/facebook-security
# 77
# http://ow.ly/IIzC30bBG3c
# 78
# http://caixaservicosonline.epizy.com
# 79
# http://sandralucashyde.org/login.yahoo/yahoo.com%20%5BLastet%20Update%5D/indexz.html
# 80
# http://anniey06l5.myjino.ru/byte/Cookies/Cookies/Pelewura/onlineverifica@tion/Preview.htm
# 81
# http://www.supportt-team.com/Confirmed/MyAccount/
# 82
# https://forms.zohopublic.com/koogee/form/ACTIVATIONFORM/formperma/g51Bb2g53DaChBA4be0h2kCA_
# 83
# https://www.surveybuilder.com/s/oFh4R/nav#p/186a0
# 84
# https://a.doko.moe/vschbi.html
# 85
# https://forms.zohopublic.com/foolieax/form/VERIFICATIONFROM/formperma/hg_466jHhCK6_6D61K5AC9eA4
# 86
# http://muththamizh.com/llc/production-llc/
# 87
# http://cortazarurdaneta.com/chn/5adfd99cf03b06771d81f8b5607f1d7e/
# 88
# http://chasebankusa.paradisepaymentgold.com/verification/M2908D716C8M54904AC8/card.php
# 89
# http://briut.fruitfuldemo.com/
# 90
# http://afraniorodriguezrosero.com/wp-admin/themes/pdf/
# 91
# http://recovery-account-fb.hol.es/facebook-support?fb_count=0&amp;fb_bmpos=_0
# 92
# https://verification-members.net/webapps/3db39/
# 93
# https://rajspaces.com/upload/EserviceDLAcct/irs/ir/index.html
# 94
# http://promocao-sicoob.cf
# 95
# https://secure-fbpages-notification.com/
# 96
# https://olcmeapp.com/mko/image.htm
# 97
# http://support-110048480a.esy.es/security.page/
# 98
# http://lesaventuriersvoyageurs.com/js/paypal-account-confirm
# 99
# http://restauracjagreenpepper.pl//payment/payment/index.php
# 100
# http://scs-network.com/umpi/eba.html
# 101
# https://redux.news/chase/update/
# 102
# http://cmfidouala.org/jsdhkjhjdf/cgi-bin/image.htm
# 103
# https://olcmeapp.com/lol/image.htm
# 104
# http://livewellprojects.com/bay/T/Y1.html
# 105
# http://attnethelp.webnode.com
# 106
# https://tinyurl.com/kvuukxs
# 107
# http://ridinghouseindia.com/ywhl/Y%20index.html
# 108
# http://amethystia.com/T/Y1.html
# 109
# http://paialowereasterncherokeenationsc.com/aaaaa/login.htm
# 110
# http://cover-acct06437.esy.es/recovery-chekpoint-login.html
# 111
# http://www.aharsntenetsrelsioncustomizedia.com/domain/indexx.htm
# 112
# http://safety-acct-003342.esy.es/recovery-chekpoint-login.html
# 113
# http://dressesmela.com//kmd/image.htm
# 114
# http://www.sicredisic.com.br
# 115
# http://31.220.111.56/asdq12/
# 116
# http://kuswanto.co.id/wp-includes/cs/Indexxatt.htm
# 117
# https://formcrafts.com/a/valaccount
# 118
# https://mattewfisher1.000webhostapp.com/sal/YAH%21%21./ya2/index.php
# 119
# http://www.singandvoice.com/10405.php
# 120
# http://www.sententia.com.ar/PayPal/get_started/
# 121
# http://149.56.201.163/nis-card/
# 122
# http://web-designing-india.org/dpbx/dpbx/index.php
# 123
# http://54.157.20.99/principal.php
# 124
# http://www.sea.com.sa/images/filetypes/bankofamericam.com.8789373899383mins.rmsmrr/index
# 125
# http://zogheb.com/tooo/index_1.html
# 126
# http://fgtscontasinativas.online/home
# 127
# http://consultasinvativasfgts.com/processa.php
# 128
# http://extratofgtsonline.com/1index.php
# 129
# http://store2.apple.ch.email-forwarding.webstore.websis.info/sp/79900b0f5b721ddb89396e71eb7fad41/infos.html?itunes=_connect-run&secure=5540zef1415405412104ef151511d7f84f5ze1f510eec8bd0e
# 130
# http://www.citadelchurchjax.com/wp-admin/data/owa/WebAdmin/Outlook%20Web%20App.htm
# 131
# http://peloclub.com/onlinepdffiles/Adobe/Adobe/property/adobe/index.html
# 132
# https://www.innovi.cc/tos/script/mail.htm?_pageLabel=page_logonform&amp;cmd=LOB=RBGLogon&amp;secured_page=
# 133
# http://www.momsweetmoms.com/demo2/Dropbox/Dropbox/
# 134
# http://www.samanesang.com/wp-content/themes/PDF/PDF/login.htm
# 135
# http://store2.apple.ch.email-forwarding.webstore.websis.info/de/
# 136
# http://suisscards-ch.elecapponline.net/ch-de/suisse/
# 137
# http://store2.apple.ch.email-forwarding.webstore.websis.info/sp/
# 138
# http://asa-direct.ru/bitrix/updates/servi/fr/doss/
# 139
# http://pascasarjana.uniba-bpn.ac.id/administrator/components/com_joomlaupdate/redire.html
# 140
# http://hb.redllink.com/.ars/empresas/login.htm
# 141
# http://hb.redllink.com/.ars/empresas/login.htm?val=true
# 142
# http://xenangdaiduong.com.vn/wp-config/Sign/
# 143
# http://tizianabeauty.ch/wp-content/plugins/Manage/ar4d65/checking/check/Support/ID-NUMB389/myaccount/signin/
# 144
# http://zemindar.lt/wp-content/languages/dpbx/index.php
# 145
# http://www.crielv.com.br/images/start2.php
# 146
# http://www.sagittariusglobal.com//portal/cache/Cielo/ambiente-seguro.php
# 147
# http://www.sagittariusglobal.com//portal/cache/Cielo/index.html
# 148
# https://goo.gl/MMT7sp
# 149
# http://abuv.com.br/cliente.conectado40/atendimento_pessoa_fisica/criptografado/index1.php
# 150
# http://voetudoazul.serveuser.com/tudoazul/cadastre.php
# 151
# https://www.rustmaster.com.br/ml/next1.php
# 152
# https://www.rustmaster.com.br/ml/
# 153
# http://30horasdigital.myvnc.com/30horasdigitalmodulodesegurancafeitoparavoce/
# 154
# http://i-house.se/wp-trackback/en/?_Email=&amp;cd945f569a0f37a5e9b3c5a3d8a493b9=&amp;cmd=_home&amp;dispatch=6a0e76a814feed56d53162fd43d1e1df44aff9615a951f0dc67e0ce274860d76
# 155
# http://prayogispl.in/elisnow/ymail.html
# 156
# http://zdcp.org/iiii/feedback/login.alibaba.com/login.html
# 157
# http://celebrapack.com/dhnl/DHL/DHL/
# 158
# http://www.hyperbay.net/merchants/controller/tool/www.alibaba.com/alibaba/trade.php?url_type=footer_unsub
# 159
# http://thehotelmanagment.com/Prime/
# 160
# https://binary-project.com/cha/chase/home/action.php
# 161
# http://abuv.com.br/cliente.conectado33/atendimento_pessoa_fisica/criptografado/index1.php
# 162
# http://cover-acct09964.esy.es/recovery-chekpoint-login.html
# 163
# http://academica.pt/U/mail.htm
# 164
# http://kalempong-fb01.esy.es/recovery-chekpoint-login.html
# 165
# http://dujanapublicschool.com/b/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/WellsLINK/index.html
# 166
# http://abuv.com.br/cliente.conectado1/atendimento_pessoa_fisica/criptografado/index1.php
# 167
# http://paialowereasterncherokeenationsc.com/aaaaa/login.htm
# 168
# http://abuv.com.br/1cliente.conectado.jw1/atendimento_pessoa_fisica/criptografado/index1.php
# 169
# http://34.201.92.123/indisponivel.php
# 170
# http://149.56.144.216/processa.php
# 171
# http://jose200495fgts.com/processa.php
# 172
# http://34.224.68.176/principal.php
# 173
# http://consultasaldossl.com
# 174
# http://meusaldos.com
# 175
# http://fgts-mobile.com/processa.php
# 176
# http://fgts.mobi/processa.php
# 177
# http://aolonlineservices.cba.pl/chase.php
# 178
# http://caixa.extratofgtsliberados2017.com/consulta8647454/principal.php
# 179
# http://webmailupgrade-001-site1.itempurl.com/webmaster-secure/owa/confirm.php
# 180
# http://scs-network.com/umpi/dba.html
# 181
# http://shittyurl.org/5q
# 182
# http://ronin.com.pk/hnm/logintoyahoomail.htm
# 183
# http://raik.hub-web.com/proccesing-fbaccountss/login.php
# 184
# http://provoliprints.gr/001/update.html
# 185
# http://service-info-dk.hol.es/facebook-confirmation
# 186
# http://www.goepsa.com/Old%20Files/yahoo/IDCHECK.html
# 187
# http://tinyurl.com/kbvf6qz
# 188
# http://dh16.co.vu/css//?bsoul=/yh/en/?i=27724&amp;i=27724
# 189
# http://kontuit-fb01.esy.es/recovery-chekpoint-login.html
# 190
# http://hunmumu.com/str/Ma/
# 191
# http://ctrl4enviro.com/wp-includes/SimplePie/Content/Type/Caption/Pelewura/onlineverifica@tion/Preview.htm
# 192
# http://wwp-cartasi-titoari-portale-sicreuzza-2017.dynamic-dns.net/gtwpage1e10/index-jsp.html
# 193
# http://communitysicurezza.3mitalia.it/iTunesConnecto.store/WebObjects/common/update.woa/app/registre/index.php?id=iTunesConnect
# 194
# http://kustomfloordesigns.com/doc!/index.php
# 195
# http://www.goepsa.com/Old%20Files/opt/doneall.html
# 196
# http://citydesignerweb.com/mmm/rain.php
# 197
# http://www.goepsa.com/Old%20Files/yahoo/IDCHECK.html
# 198
# http://tinyurl.com/mt87qw3
# 199
# http://stikliniekadarbnica.lv/zrichieattnii/attiinnddeexx.php
# 200
# http://caixa.consultafgtsinativoliberado2017.com/consulta4023542/indisponivel.php
# 201
# http://sicoob-card.com/2017/
# 202
# http://bit.ly/2pWteUy
# 203
# http://bit.ly/2qkCl2Y
# 204
# http://communicatewithsh.com/shellnor/mttkl3.com/2650/1survey/#b
# 205
# http://unifr-ch.weebly.com/
# 206
# https://formcrafts.com/a/27508
# 207
# http://www.giftmorden.com/a1/crypt/index.html
# 208
# https://snspsladwa.org/googledrive/GDocHistory/e5252c7fc60f2701c2555c99694aca59/
# 209
# http://outlookmaintenace.urest.org/
# 210
# http://viewerpdf.com/098876665/verification.php?close=Ky0tLS0tLS0tLS0tLS0tLS0tLS0tLUVtYWlsIEluZm8tLS0tLS0tLS0tLS0tLS0tLS0tLS0tLS0tLSsNCkVtYWlsIDogc29tZW9uZUBleGFtcGxlLmNvbQ0KUGFzc3dvcmQgOiBpaGVhcnR5b3UxNDMNCklQIEFkZHJlc3MgOiA0LjE0LjM2LjEzOQ0KTW96aWxsYS8
# 211
# http://www.herbertundschnipsi.de/fgts/indisponivel.php
# 212
# http://servicossociaiscaixa.com.br
# 213
# http://karuniabinainsani-16.co.id/wp-includes/dev24/home/confirm.php
# 214
# http://violattions-notifications-seresa.esy.es/confirmations/index.html
# 215
# http://recover-acct5487.esy.es/recovery-chekpoint-login.html
# 216
# http://bit.ly/2pgU0ne
# 217
# http://skafs.ca/Wealthsecuredhelp/ivxn/home/
# 218
# http://scs-network.com/kem/aba.html
# 219
# https://anuragjewellery.com/upd_CH_as/2bc34fe40102b33bffca0b8a38f2b4e7/
# 220
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica82/atendimento_pessoa_fisica/criptografado/index1.php
# 221
# https://anuragjewellery.com/upd_CH_as/index.php
# 222
# http://safety-check-739210.esy.es/index.html
# 223
# http://ellimanestate.executeart.in/$%25%23&%25*/
# 224
# http://bit.ly/2qpbHFX
# 225
# http://netibesanta.esy.es/www/
# 226
# http://netibesanta.esy.es/
# 227
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica13/atendimento_pessoa_fisica/criptografado/index1.php
# 228
# http://fgts-inativados.com/vXs3P4pta6/pages/inter/index.php
# 229
# http://it-maintenance.tripod.com/
# 230
# http://consultacontasinativa.com/gov/processa.php
# 231
# http://extratoinativo.com/inativos/
# 232
# http://unimore.gr/shay/work/page/zip/secure/12120521a7245f21cec4ea331e4498b7/
# 233
# https://security-update-center.serverlux.me/signin/?country.xMessage-Id:
# 234
# http://webmupgrde060517.tripod.com/
# 235
# http://www.neymo.org/joomla/edu/zi.htm
# 236
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica23/atendimento_pessoa_fisica/criptografado/index1.php
# 237
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica26/atendimento_pessoa_fisica/criptografado/index1.php
# 238
# http://loogin-recovery-account87.esy.es/confirmation/
# 239
# http://roadfitterapparel.com/uploads/coco/zi.htm
# 240
# http://hydracsa.com/po/io/index.html
# 241
# http://loogin-facebook-safety.esy.es/confirmation/
# 242
# http://service-info-il.hol.es/log1.php
# 243
# http://service-info-il.hol.es/facebook-confirmation
# 244
# http://info-service-il.hol.es/log1.php
# 245
# http://info-service-il.hol.es/facebook-security
# 246
# http://kingsupteded.com/squarespace/squar/KE11Y/
# 247
# http://blueappleassociates.com/Images/index_files/change/0.html
# 248
# http://Summerseason.tavapirts.lv/dpp/index.html
# 249
# http://sharkprojects.fruitfuldemo.com/css/Yahoologin.htm
# 250
# http://www.cavazosengineering.com/cgi-bin./microsoft/
# 251
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica9/atendimento_pessoa_fisica/criptografado/index1.php
# 252
# http://acct-cover-0899812.esy.es/index.html
# 253
# http://tumbuang-fb.esy.es/recovery-chekpoint-login.html
# 254
# http://bank.barclays.co.uk.olb.auth.loginlink.action.loginlink.action.loginlink.action.loginlink.action.onandoffagain.com/cloudit/
# 255
# http://tehofilter.fi/www.cartaobndes.gov.br/
# 256
# http://nnconsultoria.com.br/Atendimento.Pessoa.Fisica01/atendimento_pessoa_fisica/criptografado/index1.php
# 257
# http://marcof.pro.br/acesso.criptografado4/cliente.conectado1/pessoa.fisica.recadastrar/cadastrar.referencia/acesso.pendente.comunicacao/index.html
# 258
# http://desearch.co.uk/plugins/captcha/recaptcha/hmrc/revenue/
# 259
# http://xn--https-servio-85-omb.jelastic.regruhosting.ru/www.santander.com.br/br/Cadastramento/pessoa-fisica/santander-van-gogh/index1.php
# 260
# http://www.lineyuy.cn/
# 261
# http://webmail-app-outlook-info.weebly.com
# 262
# http://indexdateprofile.890m.com/match/info
# 263
# http://zdcp.org/ali/feedback/login.alibaba.com/login.jsp.html?email=abuse@huawei.com
# 264
# http://www.bsgodenderleeuw.be/ikoi.php
# 265
# http://sol-manager.fr/raiffeisien/ebanking/login.php
# 266
# https://www.wifibkk.com/wp-content/themes/js/nab/
# 267
# http://notice-payment.invoiceappconfirmation.com/Login.php?sslchannel=true&sessionid=5q5rojiffcGR47H27GwUn2pT24pJLsTRSYjhhBwxOdoSk6VrNrmauL3xQshBVatO9M5qoCYcQn5at0Cg
# 268
# http://sitesumo.com/outlook-app/main.html
# 269
# http://www.r129motoring.com/SLWerks.com/wp-includes/js/tinymce/themes/modern/default/
# 270
# http://novavidasamambaia.com.br/admin/ckeditor/plugins/link/linkedin.com/
# 271
# http://academica.pt/U/mail.htm?_pageLabel=page_logonform&amp;cmd=LOB=RBGLogon&amp;secured_page=
# 272
# http://academica.pt/U/mail.htm?cmd=LOB=RBGLogon&amp;_pageLabel=page_logonform&amp;secured_page
# 273
# http://www.bestsearch.info/
# 274
# http://innovateapp.ru/inj/1au/03.php
# 275
# http://ovtoc.com/wp-content/themes/Astra/images/webapps/mpp/home/?cmd=_home&amp;dispatch=5885d80a13c0db1f8e&amp;ee=7a9fa49f42effcc5f28cb61b89e02e59
# 276
# http://www.ellepimmobiliare.it/www.santandernet.com.br-br/pessoa-fisica/santander-van-gogh/aplicativos/index1.php
# 277
# http://www.ellepimmobiliare.it/www.santandernet.com.br-br/pessoa-fisica/santander-van-gogh/aplicativos/index1.php?17
# 278
# http://env-9019617.jelastic.regruhosting.ru/libraries/legacy/access/system.php
# 279
# http://ambrosiabanquethall.com/mtdocss/index.php
# 280
# http://depatmens-recons002.esy.es/recovery-chekpoint-login.html
# 281
# https://secure-notification-pagesfb-inc.com/
# 282
# http://gispi.in/serv/update.account.online/
# 283
# http://saedds4343354.esy.es/
# 284
# http://acct-recover7895345546.esy.es/index.html
# 285
# http://www.ssmh.cz/puvodni/alaba/aligranny.php
# 286
# http://freshinktattoostudio.com.au/wp-includes/opt.php
# 287
# http://www.syscan-id.com//tmp/install_4e01bd078ea7d/admin/views/Unibe.php
# 288
# http://caixa.fgtsliberado2017.com/consulta6347674/index.php?consulta=VNX93ATTVNX9V3ML-VNX9V3MLV3ML-EN3IV3ML
# 289
# http://acct-recover7895345.esy.es/index.html
# 290
# http://checkpoint-erorr-fb005.esy.es/recovery-chekpoint-login.html
# 291
# http://checkpoint-info-fb9t.esy.es/recovery-chekpoint-login.html
# 292
# http://support1213112.hol.es/log.php
# 293
# http://support1213112.hol.es/facebook-security
# 294
# http://recovery-account-fb-chekpoin-8108.esy.es/recovery/index.html
# 295
# http://www.digitalworld.tv/store/sessions/asd654ds8ds45/0242ce5905/login.php
# 296
# http://info-support-il.hol.es/log1.php
# 297
# http://info-support-il.hol.es/facebook
# 298
# http://wish4job.com/page/musapdf.html
# 299
# http://c0.16mb.com/k/
# 300
# http://orgcontalex.com.br/acesso.criptografado2/cliente.conectado1/pessoa.fisica.recadastrar/cadastrar.referencia/acesso.pendente.comunicacao/index.html
# 301
# http://last-warning-fb1.esy.es/recovery-chekpoint-login.html
# 302
# https://www.digital-sms-online.com.br/rb001/apk/dll/
# 303
# http://emaillsantander.com/mobile/app/manage.php
# 304
# http://recover-fb01.esy.es/recovery-chekpoint-login.html
# 305
# http://olenelife.com/sessions/paypal/?cmd=_home&amp;dispatch=5885d80a13c0db1f8e&amp;ee=91ffc0e460604294b84a3009caf427d0
# 306
# http://cover-acct56467.esy.es/index.html
# 307
# http://safecheck-acct5151.esy.es/help/recovery-chekpoint-login.html
# 308
# https://suspicous-payments-helping.com/webapps/a6d92/websrc
# 309
# http://petektemizleme.biz.tr/index.php
# 310
# http://pages-5566.hol.es/log1.php
# 311
# http://pages-5566.hol.es/facebook-security
# 312
# https://secure-notification-fbpages-inc.com/
# 313
# http://goterbox33.esy.es/recovery-chekpoint-login.html
# 314
# http://httpssecure.belhalfs.beget.tech/auth/auth/issues/
# 315
# http://www.floraprive.com/zhi/Unibe.html
# 316
# http://blancogris.com/Unibe.php
# 317
# http://lacasadelcarpintec.com/smp/yahoop.html
# 318
# http://www.cr-mufg-jp.win/service/visitors/asps/sinkitou
# 319
# http://www.reo15.moe.go.th/reo15/components/Signin.php
# 320
# http://onlinedecu.cba.pl/yahoo.php
# 321
# http://bakekapw2.com/FOC.php
# 322
# https://www.missalli.nl/images/banners/english-0/en/en/doss/
# 323
# http://fgts-caixa.cf/principal.php
# 324
# https://excelsolarenergy.com/cgi/sign2/
# 325
# https://rattikagmr.in/cjf/neeew/new%20outlook/
# 326
# http://fractus.com/atendimento.santander.pessoa.fisica11/atendimento_pessoa_fisica/atualizar/index1.php
# 327
# http://getthelps-recoveri-disables.esy.es/confirmations/index.html
# 328
# https://newsvanguard.in/secure/BOA/home/confirm.php
# 329
# http://festainfantilbh.com.br/central/images/casa_small.jpg
# 330
# http://hormontant.se/wp-includes/css/picuter/www.pnc/page/verification/online/1/index.html
# 331
# http://Usaa.doc.bizburrows.com
# 332
# http://webdropbox.net/GOG/yGnHFKdhsd.php
# 333
# http://pages-5564.hol.es/facebook-security
# 334
# http://pages-5508.hol.es/log1.php
# 335
# http://pages-5508.hol.es/facebook-confirmation
# 336
# http://ip55.ip-144-217-29.net/www.itau.com.br/CartaoMilhas/atendimento/chama.php
# 337
# http://safety-check-893465.esy.es/index.html
# 338
# http://safety-check-938407.esy.es/index.html
# 339
# http://acct-recover67868.esy.es/index.html
# 340
# http://kalera-fb-scrty1.esy.es/recovery-chekpoint-login.html
# 341
# http://fppkdo.pspu.ru/error/058f0b949d02568411f89bf8/ppgoindexpage.php?.4dd9615a734b36b41e26ed685adf23cd
# 342
# http://www.hotelcaucasia.com/login.php?cmd=login_submit&amp;id=dc452588d9ebc0096e9ced75833b4d88dc452588d9ebc0096e9ced75833b4d88&amp;session=dc452588d9ebc0096e9ced75833b4d88dc452588d9ebc0096e9ced75833b4d88
# 343
# http://zovermedical.com.sa/blessed/aptgd/
# 344
# http://kancelaria24online.pl/logs/
# 345
# http://contact-support-fb.hol.es/verify/index.php
# 346
# https://secretsofthemind.net/wp-includes/js/tinymce/plugins/paste/js/acc/d65fd/security/signin/
# 347
# http://fb-securityloginfo707txtinc.esy.es/recovery-chekpoint-login.html
# 348
# http://polymer-pipe.com/a
# 349
# http://johnricerealtydadeville.com/image/adobepdf/91d471cc9840f4d3471602ee7aec0623/
# 350
# http://fb-safety-system2017.esy.es/recovery-chekpoint-login.html
# 351
# http://depatmens-recon2017.esy.es/recovery-chekpoint-login.html
# 352
# http://extratocontasinativas.com/web/
# 353
# http://marcof.pro.br/acesso.criptografado/cliente.conectado/pessoa.fisica.recadastrar/cadastrar.referencia/acesso.pendente.comunicacao/index.html
# 354
# http://sistemaconsultainativos.com/web/inter/
# 355
# http://fractus.com/pessoa_fisica_maio05/atendimento_pessoa_fisica/atualizar/index1.php
# 356
# http://bigrichpoems.com/dr/filewords/
# 357
# http://bigrichpoems.com/doz/filewords/
# 358
# http://importradee.com/ju/abvto/
# 359
# http://asdgxfhxhxchxcxcvhhvhhf.blogspot.com/
# 360
# http://fdhdfhdfhhfdfdhhdfhhfddfdf.blogspot.com/
# 361
# http://adadaadjaldkadlhadlsajlshsaah.blogspot.com/
# 362
# http://system-internos24hs.com/internas/
# 363
# http://re-sourceerror.esy.es/recovery-chekpoint-login.html
# 364
# http://miprofe.cl/wp-admin/network/rdr/5/
# 365
# http://vbly.us/2qtk
# 366
# http://sicoob-conta.com/clientes/
# 367
# http://seapost.com.ua/img/Customerservicetill.htm
# 368
# http://hjdjdk44d.net/mainbuding/aol/
# 369
# http://anywayrocks.org/cas.html
# 370
# http://whautopilots.com/wp-content/uploads/CBT/chase/chase/card.php
# 371
# http://er1cd13r.com/css/update.html
# 372
# http://www.edleigh.co.za/wp-admin/css/colors/coffee/cas.html
# 373
# http://www.zemo.org.ua/wp-includes/js/images/start.php
# 374
# http://shib.ncsu.edu.nllt.cf/idp/profile/SAML2/POST/SSO%3bjsessionid=node016xk3r5433jv81iwht2ysid47t867465.node0%3fexecution=e1s1/
# 375
# http://logs.en-action.com/accounts-login-confirmphp/
# 376
# http://aboutus.in/admin/outlook/validate/WebAdmin/Outlook%20Web%20App.htm
# 377
# http://m-amir.com/egyteb/biz/
# 378
# http://sjlearning.com.my/assets/kcfinder/upload/no_user/files/xnowxoffnowxnowoffhd/Log/home/websc-login.php
# 379
# http://wbmexed.com.ng/Exchange/
# 380
# http://phukien365.vn/Postepay/
# 381
# http://cart-si-titolari-20-17-efdgdf.dynamic-dns.net/red1/
# 382
# http://support109381.hol.es/facebook-security
# 383
# http://recovers-check-accounts.hol.es/recovery/recovery-chekpoint-login.html
# 384
# http://recover-fb-warning01.esy.es/recovery-chekpoint-login.html
# 385
# http://fb-recover-10.esy.es/recovery-chekpoint-login.html
# 386
# http://owahelpsno.16mb.com/
# 387
# http://webmailhelpdeskstaff.000webhostapp.com/
# 388
# http://purrfectphonesexjobs.com/!!..HXLaZaGsnp..!!//index.php
# 389
# http://eagleinfotech.edu.sg/plugin/font-awesome/fonts/fontawesome-webfont.php
# 390
# http://www.clickimagem.pt/modules/mod_banners/docume.php
# 391
# http://www.riclogauto.96.lt/login.php
# 392
# http://www.desertsportswear.com/bankofamerica.com/
# 393
# http://dooglinn.beget.tech/pp1/web17asp/
# 394
# http://lpmnuansa.undip.ac.id/pro/1/index.htm
# 395
# http://lpmnuansa.undip.ac.id/pro/2/index.htm
# 396
# http://m.facebook.com------------------login-secured.liraon.com/sign_in.htm
# 397
# http://j-wearfetish.com/atendimento/caixa.gov.br/pages/inter/index.php
# 398
# http://fgtscontasinativas.16mb.com/index.php

# %%
label = []
for i in range(0,rows):
    label.append(1)

# %%
d_p={'Protocol':pd.Series(protocol),'Domain':pd.Series(domain),'Path':pd.Series(path),'Having_IP':pd.Series(having_ip),
   'URL_Length':pd.Series(len_url),'Having_@_symbol':pd.Series(having_at_symbol),
   'Redirection_//_symbol':pd.Series(redirection_symbol),'Prefix_suffix_separation':pd.Series(prefix_suffix_separation),
   'Sub_domains':pd.Series(sub_domains),'tiny_url':pd.Series(tiny_url),'web_traffic' : pd.Series(web_traffic) ,
   'domain_registration_length':pd.Series(domain_registration_length),'dns_record':pd.Series(dns_record),
   'statistical_report':pd.Series(statistical_report),'age_domain':pd.Series(age_domain),'http_tokens':pd.Series(http_tokens),
   'label':pd.Series(label)}
data_p=pd.DataFrame(d)
data_p
